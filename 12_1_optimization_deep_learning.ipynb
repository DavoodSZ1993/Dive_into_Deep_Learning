# %% [markdown]
# <a href="https://colab.research.google.com/github/DavoodSZ1993/Dive_into_Deep_Learning/blob/main/12_1_optimization_deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install d2l==1.0.0-alpha1.post0 --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.0/93.0 kB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.2/121.2 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 24.9 MB/s eta 0:00:00

# %% [markdown]
# ## 12.1 Optimization and Deep Learning

# %% [markdown]
# ### 12.1.1 Goal of Optimization

# %%
# %matplotlib inline
import numpy as np
import torch
from mpl_toolkits import mplot3d
from d2l import torch as d2l

# %%
def f(x):
  return x * torch.cos(np.pi * x) # f(x) = xcos(pix)

def g(x):
  return f(x) + 0.2 * torch.cos(5 * np.pi * x) # g(x) = f(x) + 0.2cos(5pix)

# %%
def annotate(text, xy, xytext):
  d2l.plt.gca().annotate(text, xy=xy, xytext=xytext,
                         arrowprops=dict(arrowstyle='->'))

# %%
x = torch.arange(0.5, 1.5, 0.01)
d2l.set_figsize((4.5, 2.5))
d2l.plot(x, [f(x), g(x)], 'x', 'risk')
annotate('min of\nempirical risk', (1.0, -1.2), (0.5, -1.1))
annotate('min of risk', (1.1, -1.05), (0.95, -0.5))
